# %% [markdown]
# <a href="https://colab.research.google.com/github/Patortiz26/IN6531-Miner-a-de-datos-2021-2/blob/main/Laboratorio_5_IN6531.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1>Laboratorio N°5</center></h1>
#
# <center><strong>IN6531: Introducción a la Minería de Datos - Primavera 2021</strong></center>

# %% [markdown]
# ##Presentación

# %% [markdown]
# ###Cuerpo Docente:
#
# - Profesor: Richard Weber
# - Auxiliar: Patricio Ortiz
# - Ayudantes: Felipe Arias, Walter Guzman, Esteban Rojas

# %% [markdown]
# ###Declaración de compromiso ético
#
# Nosotros **Integrante 1, Integrante 2 e Integrante 3** declaramos que realizamos de manera grupal los pasos de la presente actividad. También declaramos no incurrir en copia, ni compartir nuestras respuestas con otras personas ni con otros grupos. Por lo que, ratificamos que las respuestas son de nuestra propia confección y reflejan nuestro propio conocimiento.

# %% [markdown]
# ### Reglas:
#
# - Fecha de entrega: 4 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de máximo 3 personas**.
# - Para trabajar este laboratorio edite este documento `.ipynb` agregando sus respuestas donde corresponda.
# - Para cada pregunta, cuando corresponda, incluya el código fuente que utilizó para llegar a su respuesta.
# - El formato de entrega para esta actividad debe ser un archivo `.ipynb` el cual debe ser subido a U-Cursos. Basta con que uno de los integrantes haga la entrega. Si más integrantes hacen una entrega en U-Cursos, se revisará cualquiera de éstas.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Prohibidas las copias. En caso de sospecha de copia se activaran los protocolos correspondientes.
# - Pueden usar cualquer material del curso que estimen conveniente.

# %% [markdown]
# ### Objetivos del lab:
#
# - Reconocer métricas de desempeño de regresores.
# - Reforzar buenas prácticas en problemas de regresión.
# - Aplicar conocimientos a un problema abierto.

# %% [markdown]
# ##Preguntas prácticas (6.0 Puntos)

# %% [markdown]
# Para la realización de este laboratorio trabajaremos con el dataframe Housing, disponibilidazo en Github. Para más información de este dataset revisar documento adjunto en la sección Tareas.

# %%
import pandas as pd

dataframe_house = pd.read_csv('https://raw.githubusercontent.com/Patortiz26/IN6531-Miner-a-de-datos-2021-2/main/train.csv')
dataframe_house.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Pregunta 1: EDA (2 Puntos)

# %% [markdown]
# En esta sección deberá realizar un Analisis Exploratorio de los Datos disponibles. Los pasos que deberá realizar son los siguientes:
#
# 1. Descripción general de dataset: Número de datos en el dataset, número de features, tipos de cada features y rangos, etc. Aplique el preprocesamiento necesario tal que los datos queden usables para los modelos de regresión. (0.2 Puntos)
#
# 2. Análisis de valores nulos: Deberán realizar un histograma con el número de valores na por cada columna. (0.3 Puntos)
#
# 3. Análisis variable objetivo: Se les pide que creen la variable `log_Sale` en la que apliquen logaritmo sobre la columna `SalePrice`. Grafique la distribución (displot) de ambas variables. (0.2 Puntos)
#
# 4. Análisis variables númericas: Realice un displot (histograma + función de distribución) para todas las variables númericas del dataset. (0.4 Puntos)
#
# 5. Análisis variables categoricas. Realice gráficos de caja (boxplot) para la variable objetivo diferenciando por los valores de las distintas variables categoricas. (Si tienen una variable binaria: 'Si' - 'No', deben realizar un boxplot para los precios asociados a la variable == 'Si' y otro para la variable == 'No'). La librería seaborn tiene una implementación muy sencilla para este procedimiento. (0.4 Puntos)
#
# 6. Bonus: Se entregará bonus de 0.5 por realizar un análisis de correlación de las variables.
#
# 7. Finalmente, concluya a partir del análisis generado. Se les recomienda que en este paso disminuyan el número de features totales basado en análisis previos. (0.5 Puntos)

# %% [markdown]
# ###Pregunta 2: Justificación de métricas (0.8 Puntos)

# %% [markdown]
# Para enfrentar un problema de regresión existen muchas métricas que se pueden utilizar para evaluar un modelo. Al respecto, explique al menos 4 de estas métricas, que serán las que utilice para la evaluación de sus modelos en el item siguiente. (0.2 Puntos por métrica explicada)

# %% [markdown]
# ###Pregunta 3: Entrenamiento de modelos (2.0 Puntos)

# %% [markdown]
# En este item deberán entrenar y reportar las métricas de, al menos 3 modelos de regresión distintos, para cada uno de los pasos que se les presentará a continuación:
#
# (Nombre de manera distinta a los distintos modelos, pues se ocuparan luego en la sección siguiente)
#
# 1. Entrene los modelos utilizando todas las columnas númericas del dataframe. (0.3 Puntos)
# 2. Incorpore las variables categoricas a los modelos de regresión. (0.3 Puntos)
# 3. Haga una selección sobre los atributos usados de manera de tener un máximo de 10 features. (0.4 Puntos)
# 3. Sobre la selección de features anterior, mejore las métricas de los modelos ajustando los hiperparametros. (0.4 Puntos)
# 4. Comente el comportamiento de las métricas a lo largo de los 4 experimentos. De ser posible también entregue un análisis en cuanto al tiempo de demora en procesar los distintos modelos. (0.6 Puntos)

# %% [markdown]
# ###Pregunta 4: Prueba de los modelos (1.2 Puntos)

# %% [markdown]
# Ahora, utilizando los modelos entrenados en la sección 4, deberán "testear" sus modelos en el dataset de train que se les entrega. Para ello:
#
# 1. Trabaje los datos, de la misma forma en que trabajó el train set. (0.2 Puntos)
# 2. Ejecute los modelos entrenados en P3. (0.4 Puntos)
# 3. Comente los resultados, y resalte las coclusiones principales. (0.6 Puntos)

# %%
dataframe_test = pd.read_csv('https://raw.githubusercontent.com/Patortiz26/IN6531-Miner-a-de-datos-2021-2/main/test.csv')
